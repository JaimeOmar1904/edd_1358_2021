# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeOmar1904/edd_1358_2021/blob/master/25_11_2020_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Nodo:
    def __init__( self , dato, siguiente=None ):
        self.dato = dato
        self.siguiente = siguiente


class LinkedList:
    def __init__ (self ):
        self.__head = None

    def is_empty ( self ):
        return self.__head == None

    def tail (self):
        curr_node = self.__head
        while curr_node != None and curr_node.siguiente != None:
            curr_node = curr_node.siguiente
        return curr_node

    def append(self, value):
        nuevo = Nodo(value)
        if self.__head == None:
            self.__head = nuevo
        else:
            self.tail().siguiente = nuevo

    def transversal(self):
        curr_node = self.__head
        if curr_node == None:
            print("lista vacía")
        else:
            while curr_node != None:
                print(f"{curr_node.dato} --->",end="")
                curr_node = curr_node.siguiente
        print()

    def preppend(self,value):
        nuevo = Nodo(value)
        if self.__head == None:
            self.__head == nuevo
        else:
            x = self.__head
            self.__head = nuevo
            nuevo.siguiente = x

    def remove ( self, value ):
        curr_node = self.__head
        if self.__head == value:
            self.__head = self.__head.siguiente
        else:
            while curr_node.siguiente != None:
                if curr_node.siguiente.dato == value:
                    curr_node.siguiente = curr_node.siguiente.siguiente
                    break
                else:
                    curr_node = curr_node.siguiente

    def pop(self,indice = None):
        self.indice = indice 
        if indice == None:
            curr_node = self.__head
            
            while curr_node.siguiente.siguiente != None:
                curr_node = curr_node.siguiente
                remover_nodo = curr_node.siguiente
                curr_node.siguiente = curr_node.siguiente.siguiente
                print(remover_nodo.dato)
            else:
                curr_node = self.__head
                indice = curr_node

    def pop( self , pos ):
        elementos = [self.__head.dato]
        curr_node = self.__head
        while curr_node != None and curr_node.siguiente != None:
           curr_node = curr_node.siguiente
           elementos.append(curr_node.dato)
        try:
            print(f"El valor en la posicion {pos} es = {elementos [pos]}")
        except IndexError:
            print(f"La posicion {pos} no es valida")

    def pop(self, pos):
    Indice = 1
    curr_node = self.__Head
    
    while curr_node != None:
      if 1 == pos:
        print(curr_node.dato)
        self.__Head = curr_node.siguiente
        break
      a +=1
      if a == pos:
        print(curr_node.siguiente.dato)
        curr_node.siguiente = curr_node.siguiente.siguiente
        break
      curr_node = curr_node.siguiente

# %%
class Nodo:
    def __init__( self , dato, siguiente=None ):
        self.dato = dato
        self.siguiente = siguiente


class LinkedList:
    def __init__ (self ):
        self.__head = None

    def is_empty ( self ):
        return self.__head == None

    def tail (self):
        curr_node = self.__head
        while curr_node != None and curr_node.siguiente != None:
            curr_node = curr_node.siguiente
        return curr_node

    def append(self, value):
        nuevo = Nodo(value)
        if self.__head == None:
            self.__head = nuevo
        else:
            self.tail().siguiente = nuevo

    def transversal(self):
        curr_node = self.__head
        if curr_node == None:
            print("lista vacía")
        else:
            while curr_node != None:
                print(f"{curr_node.dato} --->",end="")
                curr_node = curr_node.siguiente
        print()

    def preppend(self,value):
        nuevo = Nodo(value)
        if self.__head == None:
            self.__head == nuevo
        else:
            x = self.__head
            self.__head = nuevo
            nuevo.siguiente = x

    def remove ( self, value ):
        curr_node = self.__head
        if self.__head == value:
            self.__head = self.__head.siguiente
        else:
            while curr_node.siguiente != None:
                if curr_node.siguiente.dato == value:
                    curr_node.siguiente = curr_node.siguiente.siguiente
                    break
                else:
                    curr_node = curr_node.siguiente
    def pop(self, pos):
        a = 1
        curr_node = self.__head
        while curr_node != None:
            if 1 == pos:
                print(curr_node.dato)
                self.__head = curr_node.siguiente
                break
            a +=1
            if a == pos:
                print(curr_node.siguiente.dato)
                curr_node.siguiente = curr_node.siguiente.siguiente
                break
            curr_node = curr_node.siguiente

# %%
l = LinkedList()
print(f"l está vacía? ={l.is_empty()}")
x = l.tail()
print(x)
l.append(10)
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l.append(60)
l.append(70)
l.preppend (5)
print("Eliminamos el 40 \n")
l.remove(40)
l.pop(2)
l.transversal()
# Out:
# l está vacía? =True
# None
# Eliminamos el 40
#
# 10
# 5 --->20 --->30 --->50 --->60 --->70 --->
