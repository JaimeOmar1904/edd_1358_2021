# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeOmar1904/edd_1358_2021/blob/master/Tarea_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Queue:
    def __init__(self):
        self.__data = list()

    def is_empty(self):
        return len(self.__data) == 0


    def length(self):
        return len(self.__data)

    def enqueue(self, item):
        self.__data.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.__data.pop(0)      
        else:
            return None

    def to_string(self):
        cadena = ""
        for elem in self.__data:
            cadena = cadena + "|" + elem
        cadena = cadena + "|"
        return cadena

# %%
class BoundedPriorityQueue:
    def __init__( self , niveles ):
        self.__data = [ Queue() for x in range(niveles) ]
        self.__size = 0

    def is_empty( self ):
        return self.__size == 0
    
    def length( self ):
        return self.__size
    
    def enqueue( self , prioridad , elem ):
        if prioridad < len(self.__data) and prioridad >= 0:
            self.__data[prioridad].enqueue(elem)
            self.__size +=1
        else:
            print("Prioridad fuera de rango.")
    
    def dequeue( self ):
        if not self.is_empty():
            nivel = 0
            while self.__data[nivel].is_empty():
                nivel += 1
            return self.__data[nivel].dequeue()
    
    def to_string( self ):
        for nivel in range( len(self.__data) ):
            print(f" Nivel { nivel } --> { self.__data[nivel].to_string() } ")

# %%
cpa = BoundedPriorityQueue(5)
cpa.enqueue( 4, "Maestre")
cpa.enqueue( 2, "Niños")
cpa.enqueue( 4, "Mecanicos")
cpa.enqueue( 3, "Mujeres")
cpa.enqueue( 2, "3ra Edad")
cpa.enqueue( 1, "Niñas")
cpa.enqueue( 3, "Hombres")
cpa.enqueue( 4, "Vigia")
cpa.enqueue( 5, "Capitan")
cpa.enqueue( 4, "Timonel")
cpa.to_string()
siguiente = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente}")
cpa.to_string()
siguiente1 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente1}")
cpa.to_string()
siguiente2 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente2}")
cpa.to_string()
siguiente3 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente3}")
cpa.to_string()
siguiente4 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente4}")
cpa.to_string()
siguiente5 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente5}")
cpa.to_string()
siguiente6 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente6}")
siguiente7 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente7}")
cpa.to_string()
siguiente8 = cpa.dequeue()
print(f"El siguiente de desender del barco es: {siguiente8}")
cpa.to_string()
print("No hay nadie en la cola")
print("El barco ya ha sido evacuado por completo")
# Out:
# Prioridad fuera de rango.
#  Nivel 0 --> |
#  Nivel 1 --> |Niñas|
#  Nivel 2 --> |Niños|3ra Edad|
#  Nivel 3 --> |Mujeres|Hombres|
#  Nivel 4 --> |Maestre|Mecanicos|Vigia|Timonel|
# El siguiente de desender del barco es: Niñas
#  Nivel 0 --> |
#  Nivel 1 --> |
#  Nivel 2 --> |Niños|3ra Edad|
#  Nivel 3 --> |Mujeres|Hombres|
#  Nivel 4 --> |Maestre|Mecanicos|Vigia|Timonel|
# El siguiente de desender del barco es: Niños
#  Nivel 0 --> |
#  Nivel 1 --> |
#  Nivel 2 --> |3ra Edad|
#  Nivel 3 --> |Mujeres|Hombres|
#  Nivel 4 --> |Maestre|Mecanicos|Vigia|Timonel|
# El siguiente de desender del barco es: 3ra Edad
#  Nivel 0 --> |
#  Nivel 1 --> |
#  Nivel 2 --> |
#  Nivel 3 --> |Mujeres|Hombres|
#  Nivel 4 --> |Maestre|Mecanicos|Vigia|Timonel|
# El siguiente de desender del barco es: Mujeres
#  Nivel 0 --> |
#  Nivel 1 --> |
#  Nivel 2 --> |
#  Nivel 3 --> |Hombres|
#  Nivel 4 --> |Maestre|Mecanicos|Vigia|Timonel|
# El siguiente de desender del barco es: Hombres
#  Nivel 0 --> |
# ...
